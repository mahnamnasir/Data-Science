# %% [markdown]
# <a href="https://colab.research.google.com/github/mahnamnasir/Data-Science/blob/main/Pandas_tut_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/weather_data (2).csv")
df
# Out:
#         day temperature windspeed  event
# 0  1/1/2017         32F     6 mph   Rain
# 1  1/2/2017      -99999     7 mph  Sunny
# 2  1/3/2017          28    -99999   Snow
# 3  1/4/2017      -99999         7      0
# 4  1/5/2017        32 C    -99999   Rain
# 5  1/6/2017          31         2  Sunny
# 6  1/6/2017          34         5      0

# %%
import numpy as np
new_df = df.replace(-99999,np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
import numpy as np
new_df = df.replace([-99999,0],np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_df= df

# %%
import numpy as np
new_df = df.replace({
    'temperature': -99999,
    'windspeed': -99999,
    'event': '0'
},np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
new_df = df.replace({
    -99999 :np.NaN,
    'Rain': 'Money'

})
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0  Money
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN  Money
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new = df

# %%
newq = df.replace({
    'temperature':'[A-Za-z]',
    'windspeed' : '[A-Za-z]'
},'',regex=True)
newq
# Out:
#         day temperature windspeed  event
# 0  1/1/2017          32        6    Rain
# 1  1/2/2017      -99999        7   Sunny
# 2  1/3/2017          28    -99999   Snow
# 3  1/4/2017      -99999         7      0
# 4  1/5/2017         32     -99999   Rain
# 5  1/6/2017          31         2  Sunny
# 6  1/6/2017          34         5      0

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
new_df=df.replace(['poor','average','good','exceptional'],[1,2,3,4])
new_df
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica
